# %%
import pandas as pd
import matplotlib
matplotlib.style.use('ggplot')
# %pylab inline
pylab.rcParams['figure.figsize'] = (12, 8)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Loads the seeds dataset, located at Module3/Datasets/wheat.data into a dataframe

# %%
df = pd.read_csv('/home/vgostyuzhov/Dropbox/notes/machine_learning/DAT210x/Module3/Datasets/wheat.data')

# %%
df.head()
# Out:
#    id   area  perimeter  compactness  length  width  asymmetry  groove  \
# 0   0  15.26      14.84       0.8710   5.763  3.312      2.221   5.220
# 1   1  14.88      14.57       0.8811   5.554  3.333      1.018   4.956
# 2   2  14.29      14.09       0.9050   5.291  3.337      2.699   4.825
# 3   3  13.84      13.94       0.8955   5.324  3.379      2.259   4.805
# 4   4  16.14      14.99       0.9034   5.658  3.562      1.355   5.175
#
#   wheat_type
# 0       kama
# 1       kama
# 2       kama
# 3       kama
# 4       kama

# %% [markdown]
# #### Assignment 1
# Creates a slice of your dataframe that only includes the area and perimeter features
# Creates another slice that only includes the groove and asymmetry features

# %%
df1 = df[['area','perimeter']]
df2 = df[['asymmetry','groove']]

# %% [markdown]
# Creates a histogram for the 'area and perimeter' slice, and another histogram for the 'groove and asymmetry' slice. Set the optional display parameter: alpha=0.75

# %%
df1.plot.hist(alpha=0.75)
df2.plot.hist(alpha=0.75)

# %% [markdown]
# #### Assignment 2
# 1. Create a 2d scatter plot that graphs the area and perimeter features
# 2. Create a 2d scatter plot that graphs the groove and asymmetry features
# 3. Create a 2d scatter plot that graphs the compactness and width features

# %%
df3 = df[['compactness', 'width']]

# %%
df1.plot.scatter(x='area', y='perimeter')
df2.plot.scatter(x='groove', y='asymmetry')
df3.plot.scatter(x='compactness', y='width')

# %% [markdown]
# #### Assignment 3
# Graph a 3D scatter plot using the area, perimeter, and asymmetry features. Be sure to label your axes, and use the optional display parameter c='red'.

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('Area')
ax.set_ylabel('Perimeter')
ax.set_zlabel('Asymmetry')
ax.scatter(df.area, df.perimeter, df.asymmetry, c='r', marker='.')
plt.show()

# %% [markdown]
# Graph a 3D scatter plot using the width, groove, and length features. Be sure to label your axes, and use the optional display parameter c='green'.

# %%
fig2 = plt.figure()
ax2 = fig2.add_subplot(111, projection='3d')
ax2.set_xlabel('Width')
ax2.set_ylabel('Groove')
ax2.set_zlabel('Length')
ax2.scatter(df.width, df.groove, df.length, c='g', marker='.')
plt.show()

# %% [markdown]
# #### Assignment 4
# Drop the id, area, and perimeter features from your dataset

# %%
df4 = df.drop(['id', 'area', 'perimeter'], 1)

# %% [markdown]
# Plot a parallel coordinates chart, grouped by the wheat_type feature. Be sure to set the optional display parameter alpha to 0.4

# %%
from pandas.tools.plotting import parallel_coordinates

# %%
plt.figure()
parallel_coordinates(df4, 'wheat_type', alpha=0.4)

# %% [markdown]
# #### Assignment 5
# Make all the changes required to convert the assignment from parallel coordinated into an Andrews curve plot
# Run the file and then answer the first question below

# %%
from pandas.tools.plotting import andrews_curves

# %%
plt.figure()

# %% [markdown]
# Run the file and then answer the first question below

# %%
andrews_curves(df4, 'wheat_type', alpha=0.4)

# %%
df5 = df.drop('id', 1)

# %%
andrews_curves(df5, 'wheat_type', alpha=0.4)

# %% [markdown]
# #### Assignment 6
# Drop the id column from the dataframe

# %%
df6 = df.drop('id', 1)

# %% [markdown]
# Compute the correlation matrix of your dataframe

# %%
df6.corr()
# Out:
#                  area  perimeter  compactness    length     width  asymmetry  \
# area         1.000000   0.994341     0.600312  0.645418  0.801616  -0.205876
# perimeter    0.994341   1.000000     0.520544  0.657490  0.783188  -0.196360
# compactness  0.600312   0.520544     1.000000  0.360060  0.756165  -0.315668
# length       0.645418   0.657490     0.360060  1.000000  0.197228  -0.102325
# width        0.801616   0.783188     0.756165  0.197228  1.000000  -0.249378
# asymmetry   -0.205876  -0.196360    -0.315668 -0.102325 -0.249378   1.000000
# groove       0.786096   0.813256     0.236184  0.669887  0.619865  -0.039248
#
#                groove
# area         0.786096
# perimeter    0.813256
# compactness  0.236184
# length       0.669887
# width        0.619865
# asymmetry   -0.039248
# groove       1.000000

# %% [markdown]
# Graph the correlation matrix using imshow or matshow (either or)

# %%
plt.imshow(df6.corr(), cmap=plt.cm.Blues, interpolation='nearest')
plt.colorbar()
tick_marks = [i for i in range(len(df6.columns))]
plt.xticks(tick_marks, df6.columns, rotation='vertical')
plt.yticks(tick_marks, df6.columns)
# Out:
# ([<matplotlib.axis.YTick at 0x7fc9cd69fba8>,
# ...
#  <a list of 8 Text yticklabel objects>)
